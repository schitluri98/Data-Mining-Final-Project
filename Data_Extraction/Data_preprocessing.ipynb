# %%
from pandas import read_excel
import numpy as np
import matplotlib.pyplot as plt


my_sheet = 'Data_preprocessing'
file_name = 'SemanticScholarJournalData.xlsx'
paper_df = read_excel(file_name, sheet_name = my_sheet,parse_cols = "A,E,H,N:O")

counts = paper_df['Domain'].value_counts().to_dict()
print(counts)
domain_plot = plt.bar(range(len(counts)), list(counts.values()), align='center',animated = True)
domain_plot= plt.xticks(range(len(counts)), list(counts.keys()))
domain_plot = plt.rcParams["figure.figsize"] = [12,5]
plt.xlabel('Domain of papers', fontsize=18)
plt.ylabel('Number of papers', fontsize=16)
plt.show()
# Out:
# {'General': 99, 'Health Care': 30, 'Image Recognition': 20, 'Social Media': 10, 'Automobile': 10, 'Security': 10, 'Biotechnology': 10, 'Finance': 10}

# %%
from pandas import read_excel
import numpy as np
import matplotlib.pyplot as plt


my_sheet = 'Data_preprocessing'
file_name = 'SemanticScholarJournalData.xlsx'
paper_df = read_excel(file_name, sheet_name = my_sheet,parse_cols = "A,E,H,N:O")

counts = paper_df['Technology'].value_counts().to_dict()
print(type(counts))
domain_plot = plt.bar(range(len(counts)), list(counts.values()), align='center',animated = True)
domain_plot= plt.xticks(range(len(counts)), list(counts.keys()))
domain_plot = plt.rcParams["figure.figsize"] = [12,5]
plt.xlabel('Technology', fontsize=18)
plt.ylabel('Number of papers', fontsize=16)
plt.show()
# Out:
# <class 'dict'>

# %%
from pandas import read_excel
import numpy as np
import matplotlib.pyplot as plt


my_sheet = 'Data_preprocessing'
file_name = 'SemanticScholarJournalData.xlsx'
paper_df = read_excel(file_name, sheet_name = my_sheet,parse_cols = "N,H")
sumCitation = paper_df.groupby(['Technology']).sum().to_dict()
sumCitation_dict = sumCitation['Citations']
print (sumCitation_dict)

Citations_plot = plt.bar(range(len(sumCitation_dict)), list(sumCitation_dict.values()), align='center',animated = True)
Citations_plot= plt.xticks(range(len(sumCitation_dict)), list(sumCitation_dict.keys()))
Citations_plot = plt.rcParams["figure.figsize"] = [12,5]
plt.xlabel('Technology', fontsize=18)
plt.ylabel('Number of Citations', fontsize=16)
plt.show()
# Out:
# {'Block Chain': 4970, 'Cloud Computing': 42542, 'Deep Learning': 45137, 'Internet of Things': 14083, 'Machine Learning': 52302}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


my_sheet = 'Data_preprocessing'
file_name = 'C:/Users/haris/Desktop/final.csv'
paper_df = pd.read_csv(file_name)
print(paper_df.head(4))
# Out:
#                                 Title of the Article  \
# 0  Fashion-MNIST: a Novel Image Dataset for Bench...
# 1            MLlib: Machine Learning in Apache Spark
# 2  Scaling Distributed Machine Learning with the ...
# 3  Practical Black-Box Attacks against Machine Le...
#
#                                              Authors     Published Journal  \
# 0              Han Xiao,Kashif Rasul,Roland Vollgraf                 ArXiv
# 1    Xiangrui Meng,Joseph K. Bradley,Ameet Talwalkar  J. Mach. Learn. Res.
# 2               Mu Li,David G. Andersen,Bor-Yiing Su                  OSDI
# 3  Nicolas Papernot,Patrick D. McDaniel,Ananthram...               AsiaCCS
#
#    Year of Publication                            Abstract of the article  \
# 0                 2017  We present Fashion-MNIST, a new dataset compri...
# 1                 2015  Apache Spark is a popular open-source platform...
# 2                 2014  Big data may contain big values, but also brin...
# ...
